# %%
name = "Muhammad Ahmad Amin"
age = 18
height = 5.9167
cgpa = 3.8471
score = 96.428

# %%
print("%-10s: %s" % ("Name", name))
print("%-10s: %.6s" % ("Short Name", name))
print("%-10s: %03d" % ("Age", age))
print("%-10s: %.2f ft" % ("Height", height))
print("%-10s: %+.2f" % ("CGPA", cgpa))
print("%-10s: %05.1f%%" % ("Score", score))
# Out:
# Name      : Muhammad Ahmad Amin
# Short Name: Muhamm
# Age       : 018
# Height    : 5.92 ft
# CGPA      : +3.85
# Score     : 096.4%
