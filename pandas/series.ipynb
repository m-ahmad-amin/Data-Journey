# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3], name="Math")

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# Name: Math, dtype: int64

# %%
type(s.reset_index())
# Out:
# pandas.core.frame.DataFrame
